# %%
import pandas as pd
import numpy as np
import csv

'''
let A = the first input table (or ideally, the larger one)
let B = the second input table (or ideally, the smaller one)
let jA = the join column ID of table A
let jB = the join column ID of table B
let MB = a multimap for mapping from single values to multiple rows of table B (starts out empty)
let C = the output table (starts out empty)

for each row b in table B:
   place b in multimap MB under key b(jB)

for each row a in table A:
   for each row b in multimap MB under key a(jA):
      let c = the concatenation of row a and row b
      place row c in table C
'''

TableR = pd.read_csv("r1.csv")
TableS = pd.read_csv("s1.csv")

print(TableR)
print(TableS)
# Out:
#      ID  FirstName
# 0     0  Stephanie
# 1     1      Kerry
# 2     2      Helen
# 3     3   Jennifer
# 4     5    Brandon
# ..  ...        ...
# 95  191     Gerald
# 96  192       Mary
# 97  194     Tamara
# 98  196      Debra
# 99  198    Jeffrey
#
# [100 rows x 2 columns]
#      ID  LastName
# 0     0   Huffman
# 1     7    Tilley
# 2    11  Franklin
# 3    13   Ramirez
# 4    15     Gregg
# ..  ...       ...
# 95  194     Toppa
# 96  195   Cameron
# 97  196     Jones
# 98  198     Davis
# 99  199     Bryan
#
# [100 rows x 2 columns]

# %%
#HashJoin
TableT = {}

for person in TableS["ID"]:
    if person not in TableT:
        TableT[person] = [TableS[TableS["ID"] == person].values.flatten().tolist()]
    else:
        TableT[person] = TableT[person].append( TableS[TableS["ID"] == person].values.flatten().tolist())
#(s, r) for r in table2 for s in h[r[index2]]

for index, R in TableR.iterrows():
    for S in TableT[R[0]]:
        S.append(R.values.flatten().tolist())
        
print(TableT)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-300932da8e8e> in <module>
#      10
#      11 for index, R in TableR.iterrows():
# ---> 12     for S in TableT[R[0]]:
#      13         S.append(R.values.flatten().tolist())
#      14
#
# KeyError: 1

# %%
# 2-phase Track-Join
# Initialize Table Tr|s

TableTrs = []
sent_to_R = []
sent_to_S = []

def send_to_t(index, table):
    print('%s sent %d to T' %(table, index))
    TableTrs.append([index, table])
    
def send_to_s(index, payload):
    print('%s sent %d to S' %(payload.values.flatten().tolist(), index))
    sent_to_S.append([index, payload])

def send_to_r(index, table):
    print('%s sent %d to R' %(table, index))
    sent_to_R.append([index, table])

# ->ProcessR

print(' ---> Process R ')

TableTr = {}

for index, person in TableR.iterrows():
    if person['ID'] not in TableTr:
        send_to_t(person['ID'], 'R')
        TableTr[person['ID']] = [person.values.flatten().tolist()]
    else:
        TableTr[person['ID']] = [TableTr[person['ID']], person.values.flatten().tolist()]


print(TableTr)
print(TableTrs)
print('---Barrier ProcessR----- \n ---> Process S ')

# ->ProcessS

TableTs = {}

for index, person in TableS.iterrows():
    if person['ID'] not in TableTs:
        send_to_t(person['ID'], 'S')
        TableTs[person['ID']] = [person.values.flatten().tolist()]
    else:
        TableTs[person['ID']] = [TableTs[person['ID']], person.values.flatten().tolist()]


print(TableTs)
print(TableTrs)
print('---Barrier Process S----- \n ---> Process T resumes')

# ->ProcessT after barrier

TableTrs_cpy = TableTrs
for row in TableTrs:
    if row[1] == 'R':
        for row2 in TableTrs_cpy:
            if row2[1] == 'S' and row[0] == row2[0]:
                send_to_r(row2[0], 'T')
print(sent_to_R)
print('---Ended Process T----- \n ---> Process R resumes')

# ->ProcessR after barrier

for row in sent_to_R:
    for index, row_val in TableR[TableR['ID'] == row[0]].iterrows():
        send_to_s(row[0], row_val)

print('---Ended Process R----- \n ---> Process S resumes')

# ->ProcessS after barrier

for row in sent_to_S:
    for index, row_val in TableS[TableS['ID'] == row[0]].iterrows():
        print(str(row_val.values.flatten().tolist()) + str(row[1].values.flatten().tolist()))
print('---Ended Process S-----')
# Out:
#  ---> Process R
# R sent 0 to T
# R sent 1 to T
# R sent 2 to T
# R sent 3 to T
# R sent 5 to T
# R sent 7 to T
# R sent 8 to T
# R sent 12 to T
# R sent 13 to T
# R sent 14 to T
# R sent 15 to T
# R sent 16 to T
# R sent 17 to T
# R sent 18 to T
# R sent 19 to T
# R sent 21 to T
# R sent 22 to T
# R sent 25 to T
# R sent 26 to T
# R sent 29 to T
# R sent 30 to T
# R sent 31 to T
# R sent 35 to T
# R sent 36 to T
# R sent 39 to T
# R sent 40 to T
# R sent 41 to T
# R sent 44 to T
# R sent 47 to T
# R sent 48 to T
# R sent 49 to T
# R sent 57 to T
# R sent 58 to T
# R sent 62 to T
# R sent 64 to T
# R sent 65 to T
# R sent 66 to T
# R sent 67 to T
# R sent 69 to T
# R sent 70 to T
# R sent 74 to T
# R sent 76 to T
# R sent 77 to T
# R sent 78 to T
# R sent 79 to T
# R sent 89 to T
# R sent 90 to T
# R sent 91 to T
# R sent 92 to T
# R sent 95 to T
# R sent 96 to T
# R sent 97 to T
# R sent 98 to T
# R sent 99 to T
# R sent 100 to T
# R sent 106 to T
# R sent 109 to T
# R sent 110 to T
# R sent 113 to T
# R sent 116 to T
# R sent 120 to T
# R sent 122 to T
# R sent 127 to T
# R sent 128 to T
# R sent 129 to T
# R sent 131 to T
# R sent 133 to T
# R sent 134 to T
# R sent 135 to T
# R sent 137 to T
# R sent 142 to T
# R sent 145 to T
# R sent 147 to T
# R sent 148 to T
# R sent 151 to T
# R sent 154 to T
# R sent 156 to T
# R sent 160 to T
# R sent 164 to T
# R sent 165 to T
# R sent 166 to T
# R sent 169 to T
# R sent 172 to T
# R sent 173 to T
# R sent 174 to T
# R sent 175 to T
# R sent 176 to T
# R sent 177 to T
# R sent 179 to T
# R sent 183 to T
# R sent 184 to T
# R sent 185 to T
# R sent 187 to T
# R sent 188 to T
# R sent 190 to T
# R sent 191 to T
# R sent 192 to T
# R sent 194 to T
# R sent 196 to T
# R sent 198 to T
# {0: [[0, 'Stephanie']], 1: [[1, 'Kerry']], 2: [[2, 'Helen']], 3: [[3, 'Jennifer']], 5: [[5, 'Brandon']], 7: [[7, 'Shannon']], 8: [[8, 'Lavern']], 12: [[12, 'Trena']], 13: [[13, 'Julian']], 14: [[14, 'Gary']], 15: [[15, 'Veronica']], 16: [[16, 'Alfonso']], 17: [[17, 'Edward']], 18: [[18, 'Thomas']], 19: [[19, 'Willard']], 21: [[21, 'Kimberly']], 22: [[22, 'Gloria']], 25: [[25, 'Hosea']], 26: [[26, 'Wesley']], 29: [[29, 'Bradley']], 30: [[30, 'Tim']], 31: [[31, 'Michelle']], 35: [[35, 'Jennifer']], 36: [[36, 'Kourtney']], 39: [[39, 'Molly']], 40: [[40, 'David']], 41: [[41, 'Charles']], 44: [[44, 'Cindy']], 47: [[47, 'Andrew']], 48: [[48, 'Jay']], 49: [[49, 'Mike']], 57: [[57, 'Thelma']], 58: [[58, 'Keith']], 62: [[62, 'Trudy']], 64: [[64, 'Lecia']], 65: [[65, 'Anne']], 66: [[66, 'Daniel']], 67: [[67, 'Terry']], 69: [[69, 'Frances']], 70: [[70, 'Amelia']], 74: [[74, 'Jerry']], 76: [[76, 'Aaron']], 77: [[77, 'Kimberly']], 78: [[78, 'Helen']], 79: [[79, 'Marcel']], 89: [[89, 'Christopher']], 90: [[90, 'Kalyn']], 91: [[91, 'David']], 92: [[92, 'Patsy']], 95: [[95, 'Annette']], 96: [[96, 'Darlene']], 97: [[97, 'Tracy']], 98: [[98, 'Eli']], 99: [[99, 'Julie']], 100: [[100, 'Mary']], 106: [[106, 'Clarence']], 109: [[109, 'Albert']], 110: [[110, 'Linda']], 113: [[113, 'Mary']], 116: [[116, 'Herb']], 120: [[120, 'Denise']], 122: [[122, 'Christopher']], 127: [[127, 'Demetrius']], 128: [[128, 'Eddie']], 129: [[129, 'Anita']], 131: [[131, 'Claude']], 133: [[133, 'Rob']], 134: [[134, 'Clarence']], 135: [[135, 'Jeffrey']], 137: [[137, 'Karen']], 142: [[142, 'Joel']], 145: [[145, 'Betty']], 147: [[147, 'Gladys']], 148: [[148, 'Nicholas']], 151: [[151, 'Charles']], 154: [[154, 'William']], 156: [[156, 'Lester']], 160: [[160, 'Margarita']], 164: [[164, 'Mary']], 165: [[165, 'Steve']], 166: [[166, 'Jacqueline']], 169: [[169, 'Carmen']], 172: [[172, 'Vivian']], 173: [[173, 'Exie']], 174: [[174, 'John']], 175: [[175, 'Albert']], 176: [[176, 'Gilbert']], 177: [[177, 'Javier']], 179: [[179, 'Dwight']], 183: [[183, 'Marcos']], 184: [[184, 'William']], 185: [[185, 'Rafael']], 187: [[187, 'Alan']], 188: [[188, 'Mitchell']], 190: [[190, 'Marion']], 191: [[191, 'Gerald']], 192: [[192, 'Mary']], 194: [[194, 'Tamara']], 196: [[196, 'Debra']], 198: [[198, 'Jeffrey']]}
# [[0, 'R'], [1, 'R'], [2, 'R'], [3, 'R'], [5, 'R'], [7, 'R'], [8, 'R'], [12, 'R'], [13, 'R'], [14, 'R'], [15, 'R'], [16, 'R'], [17, 'R'], [18, 'R'], [19, 'R'], [21, 'R'], [22, 'R'], [25, 'R'], [26, 'R'], [29, 'R'], [30, 'R'], [31, 'R'], [35, 'R'], [36, 'R'], [39, 'R'], [40, 'R'], [41, 'R'], [44, 'R'], [47, 'R'], [48, 'R'], [49, 'R'], [57, 'R'], [58, 'R'], [62, 'R'], [64, 'R'], [65, 'R'], [66, 'R'], [67, 'R'], [69, 'R'], [70, 'R'], [74, 'R'], [76, 'R'], [77, 'R'], [78, 'R'], [79, 'R'], [89, 'R'], [90, 'R'], [91, 'R'], [92, 'R'], [95, 'R'], [96, 'R'], [97, 'R'], [98, 'R'], [99, 'R'], [100, 'R'], [106, 'R'], [109, 'R'], [110, 'R'], [113, 'R'], [116, 'R'], [120, 'R'], [122, 'R'], [127, 'R'], [128, 'R'], [129, 'R'], [131, 'R'], [133, 'R'], [134, 'R'], [135, 'R'], [137, 'R'], [142, 'R'], [145, 'R'], [147, 'R'], [148, 'R'], [151, 'R'], [154, 'R'], [156, 'R'], [160, 'R'], [164, 'R'], [165, 'R'], [166, 'R'], [169, 'R'], [172, 'R'], [173, 'R'], [174, 'R'], [175, 'R'], [176, 'R'], [177, 'R'], [179, 'R'], [183, 'R'], [184, 'R'], [185, 'R'], [187, 'R'], [188, 'R'], [190, 'R'], [191, 'R'], [192, 'R'], [194, 'R'], [196, 'R'], [198, 'R']]
# ---Barrier ProcessR-----
#  ---> Process S
# S sent 0 to T
# S sent 7 to T
# S sent 11 to T
# S sent 13 to T
# S sent 15 to T
# S sent 18 to T
# S sent 19 to T
# S sent 21 to T
# S sent 23 to T
# S sent 24 to T
# S sent 28 to T
# S sent 31 to T
# S sent 32 to T
# S sent 33 to T
# S sent 34 to T
# S sent 35 to T
# S sent 36 to T
# S sent 42 to T
# S sent 43 to T
# S sent 44 to T
# S sent 47 to T
# S sent 49 to T
# S sent 50 to T
# S sent 51 to T
# S sent 52 to T
# S sent 53 to T
# S sent 54 to T
# S sent 60 to T
# S sent 62 to T
# S sent 63 to T
# S sent 64 to T
# S sent 67 to T
# S sent 69 to T
# S sent 70 to T
# S sent 71 to T
# S sent 72 to T
# S sent 74 to T
# S sent 75 to T
# S sent 77 to T
# S sent 78 to T
# S sent 80 to T
# S sent 81 to T
# S sent 82 to T
# S sent 85 to T
# S sent 86 to T
# S sent 88 to T
# S sent 95 to T
# S sent 96 to T
# S sent 101 to T
# S sent 102 to T
# S sent 104 to T
# S sent 105 to T
# S sent 107 to T
# S sent 108 to T
# S sent 110 to T
# S sent 111 to T
# S sent 112 to T
# S sent 113 to T
# S sent 115 to T
# S sent 117 to T
# S sent 118 to T
# S sent 119 to T
# S sent 120 to T
# S sent 121 to T
# S sent 123 to T
# S sent 128 to T
# S sent 129 to T
# S sent 136 to T
# S sent 137 to T
# S sent 138 to T
# S sent 139 to T
# S sent 140 to T
# S sent 146 to T
# S sent 148 to T
# S sent 152 to T
# S sent 162 to T
# S sent 164 to T
# S sent 166 to T
# S sent 167 to T
# S sent 168 to T
# S sent 169 to T
# S sent 171 to T
# S sent 172 to T
# S sent 173 to T
# S sent 174 to T
# S sent 176 to T
# S sent 180 to T
# S sent 184 to T
# S sent 185 to T
# S sent 186 to T
# S sent 188 to T
# S sent 189 to T
# S sent 190 to T
# S sent 192 to T
# S sent 193 to T
# S sent 194 to T
# S sent 195 to T
# S sent 196 to T
# S sent 198 to T
# S sent 199 to T
# {0: [[0, 'Huffman']], 7: [[7, 'Tilley']], 11: [[11, 'Franklin']], 13: [[13, 'Ramirez']], 15: [[15, 'Gregg']], 18: [[18, 'Stull']], 19: [[19, 'Fontenot']], 21: [[21, 'Moran']], 23: [[23, 'Andino']], 24: [[24, 'Brown']], 28: [[28, 'Espinoza']], 31: [[31, 'Shiro']], 32: [[32, 'Hernandez']], 33: [[33, 'White']], 34: [[34, 'Gassaway']], 35: [[35, 'Hambrick']], 36: [[36, 'Outen']], 42: [[42, 'Cavazos']], 43: [[43, 'Reeks']], 44: [[44, 'Campos']], 47: [[47, 'Tucker']], 49: [[49, 'Barfield']], 50: [[50, 'Fletcher']], 51: [[51, 'Aigner']], 52: [[52, 'Knight']], 53: [[53, 'Duke']], 54: [[54, 'Norfleet']], 60: [[60, 'Kiehne']], 62: [[62, 'Jones']], 63: [[63, 'Leeper']], 64: [[64, 'Brown']], 67: [[67, 'Daley']], 69: [[69, 'Hittle']], 70: [[70, 'Lajoie']], 71: [[71, 'Shoemaker']], 72: [[72, 'Tran']], 74: [[74, 'Downey']], 75: [[75, 'Rogers']], 77: [[77, 'Copeland']], 78: [[78, 'Harrington']], 80: [[80, 'Sandy']], 81: [[81, 'Fuller']], 82: [[82, 'Black']], 85: [[85, 'Reaves']], 86: [[86, 'Harvey']], 88: [[88, 'Fleming']], 95: [[95, 'Brown']], 96: [[96, 'Conn']], 101: [[101, 'Rave']], 102: [[102, 'Evans']], 104: [[104, 'Caceres']], 105: [[105, 'Crawford']], 107: [[107, 'Wallace']], 108: [[108, 'Boots']], 110: [[110, 'Kendall']], 111: [[111, 'Dooley']], 112: [[112, 'Rush']], 113: [[113, 'Walls']], 115: [[115, 'Olson']], 117: [[117, 'Edmond']], 118: [[118, 'Wikoff']], 119: [[119, 'Watson']], 120: [[120, 'Richmond']], 121: [[121, 'Bingham']], 123: [[123, 'Nelson']], 128: [[128, 'Scholl']], 129: [[129, 'Rouse']], 136: [[136, 'Wright']], 137: [[137, 'Tyler']], 138: [[138, 'Miller']], 139: [[139, 'Crespino']], 140: [[140, 'Frizzell']], 146: [[146, 'Lewis']], 148: [[148, 'Wood']], 152: [[152, 'Clark']], 162: [[162, 'Williamson']], 164: [[164, 'Gillard']], 166: [[166, 'Cottrill']], 167: [[167, 'Dupre']], 168: [[168, 'Mcguire']], 169: [[169, 'Alexander']], 171: [[171, 'Huang']], 172: [[172, 'Mccabe']], 173: [[173, 'Aldrich']], 174: [[174, 'Moore']], 176: [[176, 'Estes']], 180: [[180, 'Somerville']], 184: [[184, 'Hamlett']], 185: [[185, 'Adkins']], 186: [[186, 'Pawlicki']], 188: [[188, 'Delgado']], 189: [[189, 'Gildersleeve']], 190: [[190, 'Hayes']], 192: [[192, 'Wasmund']], 193: [[193, 'Goss']], 194: [[194, 'Toppa']], 195: [[195, 'Cameron']], 196: [[196, 'Jones']], 198: [[198, 'Davis']], 199: [[199, 'Bryan']]}
# [[0, 'R'], [1, 'R'], [2, 'R'], [3, 'R'], [5, 'R'], [7, 'R'], [8, 'R'], [12, 'R'], [13, 'R'], [14, 'R'], [15, 'R'], [16, 'R'], [17, 'R'], [18, 'R'], [19, 'R'], [21, 'R'], [22, 'R'], [25, 'R'], [26, 'R'], [29, 'R'], [30, 'R'], [31, 'R'], [35, 'R'], [36, 'R'], [39, 'R'], [40, 'R'], [41, 'R'], [44, 'R'], [47, 'R'], [48, 'R'], [49, 'R'], [57, 'R'], [58, 'R'], [62, 'R'], [64, 'R'], [65, 'R'], [66, 'R'], [67, 'R'], [69, 'R'], [70, 'R'], [74, 'R'], [76, 'R'], [77, 'R'], [78, 'R'], [79, 'R'], [89, 'R'], [90, 'R'], [91, 'R'], [92, 'R'], [95, 'R'], [96, 'R'], [97, 'R'], [98, 'R'], [99, 'R'], [100, 'R'], [106, 'R'], [109, 'R'], [110, 'R'], [113, 'R'], [116, 'R'], [120, 'R'], [122, 'R'], [127, 'R'], [128, 'R'], [129, 'R'], [131, 'R'], [133, 'R'], [134, 'R'], [135, 'R'], [137, 'R'], [142, 'R'], [145, 'R'], [147, 'R'], [148, 'R'], [151, 'R'], [154, 'R'], [156, 'R'], [160, 'R'], [164, 'R'], [165, 'R'], [166, 'R'], [169, 'R'], [172, 'R'], [173, 'R'], [174, 'R'], [175, 'R'], [176, 'R'], [177, 'R'], [179, 'R'], [183, 'R'], [184, 'R'], [185, 'R'], [187, 'R'], [188, 'R'], [190, 'R'], [191, 'R'], [192, 'R'], [194, 'R'], [196, 'R'], [198, 'R'], [0, 'S'], [7, 'S'], [11, 'S'], [13, 'S'], [15, 'S'], [18, 'S'], [19, 'S'], [21, 'S'], [23, 'S'], [24, 'S'], [28, 'S'], [31, 'S'], [32, 'S'], [33, 'S'], [34, 'S'], [35, 'S'], [36, 'S'], [42, 'S'], [43, 'S'], [44, 'S'], [47, 'S'], [49, 'S'], [50, 'S'], [51, 'S'], [52, 'S'], [53, 'S'], [54, 'S'], [60, 'S'], [62, 'S'], [63, 'S'], [64, 'S'], [67, 'S'], [69, 'S'], [70, 'S'], [71, 'S'], [72, 'S'], [74, 'S'], [75, 'S'], [77, 'S'], [78, 'S'], [80, 'S'], [81, 'S'], [82, 'S'], [85, 'S'], [86, 'S'], [88, 'S'], [95, 'S'], [96, 'S'], [101, 'S'], [102, 'S'], [104, 'S'], [105, 'S'], [107, 'S'], [108, 'S'], [110, 'S'], [111, 'S'], [112, 'S'], [113, 'S'], [115, 'S'], [117, 'S'], [118, 'S'], [119, 'S'], [120, 'S'], [121, 'S'], [123, 'S'], [128, 'S'], [129, 'S'], [136, 'S'], [137, 'S'], [138, 'S'], [139, 'S'], [140, 'S'], [146, 'S'], [148, 'S'], [152, 'S'], [162, 'S'], [164, 'S'], [166, 'S'], [167, 'S'], [168, 'S'], [169, 'S'], [171, 'S'], [172, 'S'], [173, 'S'], [174, 'S'], [176, 'S'], [180, 'S'], [184, 'S'], [185, 'S'], [186, 'S'], [188, 'S'], [189, 'S'], [190, 'S'], [192, 'S'], [193, 'S'], [194, 'S'], [195, 'S'], [196, 'S'], [198, 'S'], [199, 'S']]
# ---Barrier Process S-----
#  ---> Process T resumes
# T sent 0 to R
# T sent 7 to R
# T sent 13 to R
# T sent 15 to R
# T sent 18 to R
# T sent 19 to R
# T sent 21 to R
# T sent 31 to R
# T sent 35 to R
# T sent 36 to R
# T sent 44 to R
# T sent 47 to R
# T sent 49 to R
# T sent 62 to R
# T sent 64 to R
# T sent 67 to R
# T sent 69 to R
# T sent 70 to R
# T sent 74 to R
# T sent 77 to R
# T sent 78 to R
# T sent 95 to R
# T sent 96 to R
# T sent 110 to R
# T sent 113 to R
# T sent 120 to R
# T sent 128 to R
# T sent 129 to R
# T sent 137 to R
# T sent 148 to R
# T sent 164 to R
# T sent 166 to R
# T sent 169 to R
# T sent 172 to R
# T sent 173 to R
# T sent 174 to R
# T sent 176 to R
# T sent 184 to R
# T sent 185 to R
# T sent 188 to R
# T sent 190 to R
# T sent 192 to R
# T sent 194 to R
# T sent 196 to R
# T sent 198 to R
# [[0, 'T'], [7, 'T'], [13, 'T'], [15, 'T'], [18, 'T'], [19, 'T'], [21, 'T'], [31, 'T'], [35, 'T'], [36, 'T'], [44, 'T'], [47, 'T'], [49, 'T'], [62, 'T'], [64, 'T'], [67, 'T'], [69, 'T'], [70, 'T'], [74, 'T'], [77, 'T'], [78, 'T'], [95, 'T'], [96, 'T'], [110, 'T'], [113, 'T'], [120, 'T'], [128, 'T'], [129, 'T'], [137, 'T'], [148, 'T'], [164, 'T'], [166, 'T'], [169, 'T'], [172, 'T'], [173, 'T'], [174, 'T'], [176, 'T'], [184, 'T'], [185, 'T'], [188, 'T'], [190, 'T'], [192, 'T'], [194, 'T'], [196, 'T'], [198, 'T']]
# ---Ended Process T-----
#  ---> Process R resumes
# [0, 'Stephanie'] sent 0 to S
# [7, 'Shannon'] sent 7 to S
# [13, 'Julian'] sent 13 to S
# [15, 'Veronica'] sent 15 to S
# [18, 'Thomas'] sent 18 to S
# [19, 'Willard'] sent 19 to S
# [21, 'Kimberly'] sent 21 to S
# [31, 'Michelle'] sent 31 to S
# [35, 'Jennifer'] sent 35 to S
# [36, 'Kourtney'] sent 36 to S
# [44, 'Cindy'] sent 44 to S
# [47, 'Andrew'] sent 47 to S
# [49, 'Mike'] sent 49 to S
# [62, 'Trudy'] sent 62 to S
# [64, 'Lecia'] sent 64 to S
# [67, 'Terry'] sent 67 to S
# [69, 'Frances'] sent 69 to S
# [70, 'Amelia'] sent 70 to S
# [74, 'Jerry'] sent 74 to S
# [77, 'Kimberly'] sent 77 to S
# [78, 'Helen'] sent 78 to S
# [95, 'Annette'] sent 95 to S
# [96, 'Darlene'] sent 96 to S
# [110, 'Linda'] sent 110 to S
# [113, 'Mary'] sent 113 to S
# [120, 'Denise'] sent 120 to S
# [128, 'Eddie'] sent 128 to S
# [129, 'Anita'] sent 129 to S
# [137, 'Karen'] sent 137 to S
# [148, 'Nicholas'] sent 148 to S
# [164, 'Mary'] sent 164 to S
# [166, 'Jacqueline'] sent 166 to S
# [169, 'Carmen'] sent 169 to S
# [172, 'Vivian'] sent 172 to S
# [173, 'Exie'] sent 173 to S
# [174, 'John'] sent 174 to S
# [176, 'Gilbert'] sent 176 to S
# [184, 'William'] sent 184 to S
# [185, 'Rafael'] sent 185 to S
# [188, 'Mitchell'] sent 188 to S
# [190, 'Marion'] sent 190 to S
# [192, 'Mary'] sent 192 to S
# [194, 'Tamara'] sent 194 to S
# [196, 'Debra'] sent 196 to S
# [198, 'Jeffrey'] sent 198 to S
# ---Ended Process R-----
#  ---> Process S resumes
# [0, 'Huffman'][0, 'Stephanie']
# [7, 'Tilley'][7, 'Shannon']
# [13, 'Ramirez'][13, 'Julian']
# [15, 'Gregg'][15, 'Veronica']
# [18, 'Stull'][18, 'Thomas']
# [19, 'Fontenot'][19, 'Willard']
# [21, 'Moran'][21, 'Kimberly']
# [31, 'Shiro'][31, 'Michelle']
# [35, 'Hambrick'][35, 'Jennifer']
# [36, 'Outen'][36, 'Kourtney']
# [44, 'Campos'][44, 'Cindy']
# [47, 'Tucker'][47, 'Andrew']
# [49, 'Barfield'][49, 'Mike']
# [62, 'Jones'][62, 'Trudy']
# [64, 'Brown'][64, 'Lecia']
# [67, 'Daley'][67, 'Terry']
# [69, 'Hittle'][69, 'Frances']
# [70, 'Lajoie'][70, 'Amelia']
# [74, 'Downey'][74, 'Jerry']
# [77, 'Copeland'][77, 'Kimberly']
# [78, 'Harrington'][78, 'Helen']
# [95, 'Brown'][95, 'Annette']
# [96, 'Conn'][96, 'Darlene']
# [110, 'Kendall'][110, 'Linda']
# [113, 'Walls'][113, 'Mary']
# [120, 'Richmond'][120, 'Denise']
# [128, 'Scholl'][128, 'Eddie']
# [129, 'Rouse'][129, 'Anita']
# [137, 'Tyler'][137, 'Karen']
# [148, 'Wood'][148, 'Nicholas']
# [164, 'Gillard'][164, 'Mary']
# [166, 'Cottrill'][166, 'Jacqueline']
# [169, 'Alexander'][169, 'Carmen']
# [172, 'Mccabe'][172, 'Vivian']
# [173, 'Aldrich'][173, 'Exie']
# [174, 'Moore'][174, 'John']
# [176, 'Estes'][176, 'Gilbert']
# [184, 'Hamlett'][184, 'William']
# [185, 'Adkins'][185, 'Rafael']
# [188, 'Delgado'][188, 'Mitchell']
# [190, 'Hayes'][190, 'Marion']
# [192, 'Wasmund'][192, 'Mary']
# [194, 'Toppa'][194, 'Tamara']
# [196, 'Jones'][196, 'Debra']
# [198, 'Davis'][198, 'Jeffrey']
# ---Ended Process S-----

# %%
# 2-phase Track-Join
# Initialize Table Tr|s

TableTrs = []
sent_to_R = []
sent_to_S = []

def send_to_t(index, table):
    print('%s sent %d to T' %(table, index))
    TableTrs.append([index, table])
    
def send_to_s(index, payload):
    print('%s sent %d to S' %(payload.values.flatten().tolist(), index))
    sent_to_S.append([index, payload])

def send_to_r(index, table):
    print('%s sent %d to R' %(table, index))
    sent_to_R.append([index, table])

# ->ProcessR

print(' ---> Process R ')

TableTr = {}

for index, person in TableR.iterrows():
    if person['ID'] not in TableTr:
        send_to_t(person['ID'], 'R')
        TableTr[person['ID']] = [person.values.flatten().tolist()]
    else:
        TableTr[person['ID']] = [TableTr[person['ID']], person.values.flatten().tolist()]


print(TableTr)
print(TableTrs)
print('---Barrier ProcessR----- \n ---> Process S ')

# ->ProcessS

TableTs = {}

for index, person in TableS.iterrows():
    if person['ID'] not in TableTs:
        send_to_t(person['ID'], 'S')
        TableTs[person['ID']] = [person.values.flatten().tolist()]
    else:
        TableTs[person['ID']] = [TableTs[person['ID']], person.values.flatten().tolist()]


print(TableTs)
print(TableTrs)
print('---Barrier Process S----- \n ---> Process T resumes')

# ->ProcessT after barrier

TableTrs_cpy = TableTrs
for row in TableTrs:
    if row[1] == 'R':
        for row2 in TableTrs_cpy:
            if row2[1] == 'S' and row[0] == row2[0]:
                send_to_r(row2[0], 'T')
print(sent_to_R)
print('---Ended Process T----- \n ---> Process R resumes')

# ->ProcessR after barrier

for row in sent_to_R:
    for index, row_val in TableR[TableR['ID'] == row[0]].iterrows():
        send_to_s(row[0], row_val)

print('---Ended Process R----- \n ---> Process S resumes')

# ->ProcessS after barrier

for row in sent_to_S:
    for index, row_val in TableS[TableS['ID'] == row[0]].iterrows():
        print(str(row_val.values.flatten().tolist()) + str(row[1].values.flatten().tolist()))
print('---Ended Process S-----')
# Out:
#  ---> Process R
# R sent 0 to T
# R sent 1 to T
# R sent 2 to T
# R sent 3 to T
# R sent 5 to T
# R sent 7 to T
# R sent 8 to T
# R sent 12 to T
# R sent 13 to T
# R sent 14 to T
# R sent 15 to T
# R sent 16 to T
# R sent 17 to T
# R sent 18 to T
# R sent 19 to T
# R sent 21 to T
# R sent 22 to T
# R sent 25 to T
# R sent 26 to T
# R sent 29 to T
# R sent 30 to T
# R sent 31 to T
# R sent 35 to T
# R sent 36 to T
# R sent 39 to T
# R sent 40 to T
# R sent 41 to T
# R sent 44 to T
# R sent 47 to T
# R sent 48 to T
# R sent 49 to T
# R sent 57 to T
# R sent 58 to T
# R sent 62 to T
# R sent 64 to T
# R sent 65 to T
# R sent 66 to T
# R sent 67 to T
# R sent 69 to T
# R sent 70 to T
# R sent 74 to T
# R sent 76 to T
# R sent 77 to T
# R sent 78 to T
# R sent 79 to T
# R sent 89 to T
# R sent 90 to T
# R sent 91 to T
# R sent 92 to T
# R sent 95 to T
# R sent 96 to T
# R sent 97 to T
# R sent 98 to T
# R sent 99 to T
# R sent 100 to T
# R sent 106 to T
# R sent 109 to T
# R sent 110 to T
# R sent 113 to T
# R sent 116 to T
# R sent 120 to T
# R sent 122 to T
# R sent 127 to T
# R sent 128 to T
# R sent 129 to T
# R sent 131 to T
# R sent 133 to T
# R sent 134 to T
# R sent 135 to T
# R sent 137 to T
# R sent 142 to T
# R sent 145 to T
# R sent 147 to T
# R sent 148 to T
# R sent 151 to T
# R sent 154 to T
# R sent 156 to T
# R sent 160 to T
# R sent 164 to T
# R sent 165 to T
# R sent 166 to T
# R sent 169 to T
# R sent 172 to T
# R sent 173 to T
# R sent 174 to T
# R sent 175 to T
# R sent 176 to T
# R sent 177 to T
# R sent 179 to T
# R sent 183 to T
# R sent 184 to T
# R sent 185 to T
# R sent 187 to T
# R sent 188 to T
# R sent 190 to T
# R sent 191 to T
# R sent 192 to T
# R sent 194 to T
# R sent 196 to T
# R sent 198 to T
# {0: [[0, 'Stephanie']], 1: [[1, 'Kerry']], 2: [[2, 'Helen']], 3: [[3, 'Jennifer']], 5: [[5, 'Brandon']], 7: [[7, 'Shannon']], 8: [[8, 'Lavern']], 12: [[12, 'Trena']], 13: [[13, 'Julian']], 14: [[14, 'Gary']], 15: [[15, 'Veronica']], 16: [[16, 'Alfonso']], 17: [[17, 'Edward']], 18: [[18, 'Thomas']], 19: [[19, 'Willard']], 21: [[21, 'Kimberly']], 22: [[22, 'Gloria']], 25: [[25, 'Hosea']], 26: [[26, 'Wesley']], 29: [[29, 'Bradley']], 30: [[30, 'Tim']], 31: [[31, 'Michelle']], 35: [[35, 'Jennifer']], 36: [[36, 'Kourtney']], 39: [[39, 'Molly']], 40: [[40, 'David']], 41: [[41, 'Charles']], 44: [[44, 'Cindy']], 47: [[47, 'Andrew']], 48: [[48, 'Jay']], 49: [[49, 'Mike']], 57: [[57, 'Thelma']], 58: [[58, 'Keith']], 62: [[62, 'Trudy']], 64: [[64, 'Lecia']], 65: [[65, 'Anne']], 66: [[66, 'Daniel']], 67: [[67, 'Terry']], 69: [[69, 'Frances']], 70: [[70, 'Amelia']], 74: [[74, 'Jerry']], 76: [[76, 'Aaron']], 77: [[77, 'Kimberly']], 78: [[78, 'Helen']], 79: [[79, 'Marcel']], 89: [[89, 'Christopher']], 90: [[90, 'Kalyn']], 91: [[91, 'David']], 92: [[92, 'Patsy']], 95: [[95, 'Annette']], 96: [[96, 'Darlene']], 97: [[97, 'Tracy']], 98: [[98, 'Eli']], 99: [[99, 'Julie']], 100: [[100, 'Mary']], 106: [[106, 'Clarence']], 109: [[109, 'Albert']], 110: [[110, 'Linda']], 113: [[113, 'Mary']], 116: [[116, 'Herb']], 120: [[120, 'Denise']], 122: [[122, 'Christopher']], 127: [[127, 'Demetrius']], 128: [[128, 'Eddie']], 129: [[129, 'Anita']], 131: [[131, 'Claude']], 133: [[133, 'Rob']], 134: [[134, 'Clarence']], 135: [[135, 'Jeffrey']], 137: [[137, 'Karen']], 142: [[142, 'Joel']], 145: [[145, 'Betty']], 147: [[147, 'Gladys']], 148: [[148, 'Nicholas']], 151: [[151, 'Charles']], 154: [[154, 'William']], 156: [[156, 'Lester']], 160: [[160, 'Margarita']], 164: [[164, 'Mary']], 165: [[165, 'Steve']], 166: [[166, 'Jacqueline']], 169: [[169, 'Carmen']], 172: [[172, 'Vivian']], 173: [[173, 'Exie']], 174: [[174, 'John']], 175: [[175, 'Albert']], 176: [[176, 'Gilbert']], 177: [[177, 'Javier']], 179: [[179, 'Dwight']], 183: [[183, 'Marcos']], 184: [[184, 'William']], 185: [[185, 'Rafael']], 187: [[187, 'Alan']], 188: [[188, 'Mitchell']], 190: [[190, 'Marion']], 191: [[191, 'Gerald']], 192: [[192, 'Mary']], 194: [[194, 'Tamara']], 196: [[196, 'Debra']], 198: [[198, 'Jeffrey']]}
# [[0, 'R'], [1, 'R'], [2, 'R'], [3, 'R'], [5, 'R'], [7, 'R'], [8, 'R'], [12, 'R'], [13, 'R'], [14, 'R'], [15, 'R'], [16, 'R'], [17, 'R'], [18, 'R'], [19, 'R'], [21, 'R'], [22, 'R'], [25, 'R'], [26, 'R'], [29, 'R'], [30, 'R'], [31, 'R'], [35, 'R'], [36, 'R'], [39, 'R'], [40, 'R'], [41, 'R'], [44, 'R'], [47, 'R'], [48, 'R'], [49, 'R'], [57, 'R'], [58, 'R'], [62, 'R'], [64, 'R'], [65, 'R'], [66, 'R'], [67, 'R'], [69, 'R'], [70, 'R'], [74, 'R'], [76, 'R'], [77, 'R'], [78, 'R'], [79, 'R'], [89, 'R'], [90, 'R'], [91, 'R'], [92, 'R'], [95, 'R'], [96, 'R'], [97, 'R'], [98, 'R'], [99, 'R'], [100, 'R'], [106, 'R'], [109, 'R'], [110, 'R'], [113, 'R'], [116, 'R'], [120, 'R'], [122, 'R'], [127, 'R'], [128, 'R'], [129, 'R'], [131, 'R'], [133, 'R'], [134, 'R'], [135, 'R'], [137, 'R'], [142, 'R'], [145, 'R'], [147, 'R'], [148, 'R'], [151, 'R'], [154, 'R'], [156, 'R'], [160, 'R'], [164, 'R'], [165, 'R'], [166, 'R'], [169, 'R'], [172, 'R'], [173, 'R'], [174, 'R'], [175, 'R'], [176, 'R'], [177, 'R'], [179, 'R'], [183, 'R'], [184, 'R'], [185, 'R'], [187, 'R'], [188, 'R'], [190, 'R'], [191, 'R'], [192, 'R'], [194, 'R'], [196, 'R'], [198, 'R']]
# ---Barrier ProcessR-----
#  ---> Process S
# S sent 0 to T
# S sent 7 to T
# S sent 11 to T
# S sent 13 to T
# S sent 15 to T
# S sent 18 to T
# S sent 19 to T
# S sent 21 to T
# S sent 23 to T
# S sent 24 to T
# S sent 28 to T
# S sent 31 to T
# S sent 32 to T
# S sent 33 to T
# S sent 34 to T
# S sent 35 to T
# S sent 36 to T
# S sent 42 to T
# S sent 43 to T
# S sent 44 to T
# S sent 47 to T
# S sent 49 to T
# S sent 50 to T
# S sent 51 to T
# S sent 52 to T
# S sent 53 to T
# S sent 54 to T
# S sent 60 to T
# S sent 62 to T
# S sent 63 to T
# S sent 64 to T
# S sent 67 to T
# S sent 69 to T
# S sent 70 to T
# S sent 71 to T
# S sent 72 to T
# S sent 74 to T
# S sent 75 to T
# S sent 77 to T
# S sent 78 to T
# S sent 80 to T
# S sent 81 to T
# S sent 82 to T
# S sent 85 to T
# S sent 86 to T
# S sent 88 to T
# S sent 95 to T
# S sent 96 to T
# S sent 101 to T
# S sent 102 to T
# S sent 104 to T
# S sent 105 to T
# S sent 107 to T
# S sent 108 to T
# S sent 110 to T
# S sent 111 to T
# S sent 112 to T
# S sent 113 to T
# S sent 115 to T
# S sent 117 to T
# S sent 118 to T
# S sent 119 to T
# S sent 120 to T
# S sent 121 to T
# S sent 123 to T
# S sent 128 to T
# S sent 129 to T
# S sent 136 to T
# S sent 137 to T
# S sent 138 to T
# S sent 139 to T
# S sent 140 to T
# S sent 146 to T
# S sent 148 to T
# S sent 152 to T
# S sent 162 to T
# S sent 164 to T
# S sent 166 to T
# S sent 167 to T
# S sent 168 to T
# S sent 169 to T
# S sent 171 to T
# S sent 172 to T
# S sent 173 to T
# S sent 174 to T
# S sent 176 to T
# S sent 180 to T
# S sent 184 to T
# S sent 185 to T
# S sent 186 to T
# S sent 188 to T
# S sent 189 to T
# S sent 190 to T
# S sent 192 to T
# S sent 193 to T
# S sent 194 to T
# S sent 195 to T
# S sent 196 to T
# S sent 198 to T
# S sent 199 to T
# {0: [[0, 'Huffman']], 7: [[7, 'Tilley']], 11: [[11, 'Franklin']], 13: [[13, 'Ramirez']], 15: [[15, 'Gregg']], 18: [[18, 'Stull']], 19: [[19, 'Fontenot']], 21: [[21, 'Moran']], 23: [[23, 'Andino']], 24: [[24, 'Brown']], 28: [[28, 'Espinoza']], 31: [[31, 'Shiro']], 32: [[32, 'Hernandez']], 33: [[33, 'White']], 34: [[34, 'Gassaway']], 35: [[35, 'Hambrick']], 36: [[36, 'Outen']], 42: [[42, 'Cavazos']], 43: [[43, 'Reeks']], 44: [[44, 'Campos']], 47: [[47, 'Tucker']], 49: [[49, 'Barfield']], 50: [[50, 'Fletcher']], 51: [[51, 'Aigner']], 52: [[52, 'Knight']], 53: [[53, 'Duke']], 54: [[54, 'Norfleet']], 60: [[60, 'Kiehne']], 62: [[62, 'Jones']], 63: [[63, 'Leeper']], 64: [[64, 'Brown']], 67: [[67, 'Daley']], 69: [[69, 'Hittle']], 70: [[70, 'Lajoie']], 71: [[71, 'Shoemaker']], 72: [[72, 'Tran']], 74: [[74, 'Downey']], 75: [[75, 'Rogers']], 77: [[77, 'Copeland']], 78: [[78, 'Harrington']], 80: [[80, 'Sandy']], 81: [[81, 'Fuller']], 82: [[82, 'Black']], 85: [[85, 'Reaves']], 86: [[86, 'Harvey']], 88: [[88, 'Fleming']], 95: [[95, 'Brown']], 96: [[96, 'Conn']], 101: [[101, 'Rave']], 102: [[102, 'Evans']], 104: [[104, 'Caceres']], 105: [[105, 'Crawford']], 107: [[107, 'Wallace']], 108: [[108, 'Boots']], 110: [[110, 'Kendall']], 111: [[111, 'Dooley']], 112: [[112, 'Rush']], 113: [[113, 'Walls']], 115: [[115, 'Olson']], 117: [[117, 'Edmond']], 118: [[118, 'Wikoff']], 119: [[119, 'Watson']], 120: [[120, 'Richmond']], 121: [[121, 'Bingham']], 123: [[123, 'Nelson']], 128: [[128, 'Scholl']], 129: [[129, 'Rouse']], 136: [[136, 'Wright']], 137: [[137, 'Tyler']], 138: [[138, 'Miller']], 139: [[139, 'Crespino']], 140: [[140, 'Frizzell']], 146: [[146, 'Lewis']], 148: [[148, 'Wood']], 152: [[152, 'Clark']], 162: [[162, 'Williamson']], 164: [[164, 'Gillard']], 166: [[166, 'Cottrill']], 167: [[167, 'Dupre']], 168: [[168, 'Mcguire']], 169: [[169, 'Alexander']], 171: [[171, 'Huang']], 172: [[172, 'Mccabe']], 173: [[173, 'Aldrich']], 174: [[174, 'Moore']], 176: [[176, 'Estes']], 180: [[180, 'Somerville']], 184: [[184, 'Hamlett']], 185: [[185, 'Adkins']], 186: [[186, 'Pawlicki']], 188: [[188, 'Delgado']], 189: [[189, 'Gildersleeve']], 190: [[190, 'Hayes']], 192: [[192, 'Wasmund']], 193: [[193, 'Goss']], 194: [[194, 'Toppa']], 195: [[195, 'Cameron']], 196: [[196, 'Jones']], 198: [[198, 'Davis']], 199: [[199, 'Bryan']]}
# [[0, 'R'], [1, 'R'], [2, 'R'], [3, 'R'], [5, 'R'], [7, 'R'], [8, 'R'], [12, 'R'], [13, 'R'], [14, 'R'], [15, 'R'], [16, 'R'], [17, 'R'], [18, 'R'], [19, 'R'], [21, 'R'], [22, 'R'], [25, 'R'], [26, 'R'], [29, 'R'], [30, 'R'], [31, 'R'], [35, 'R'], [36, 'R'], [39, 'R'], [40, 'R'], [41, 'R'], [44, 'R'], [47, 'R'], [48, 'R'], [49, 'R'], [57, 'R'], [58, 'R'], [62, 'R'], [64, 'R'], [65, 'R'], [66, 'R'], [67, 'R'], [69, 'R'], [70, 'R'], [74, 'R'], [76, 'R'], [77, 'R'], [78, 'R'], [79, 'R'], [89, 'R'], [90, 'R'], [91, 'R'], [92, 'R'], [95, 'R'], [96, 'R'], [97, 'R'], [98, 'R'], [99, 'R'], [100, 'R'], [106, 'R'], [109, 'R'], [110, 'R'], [113, 'R'], [116, 'R'], [120, 'R'], [122, 'R'], [127, 'R'], [128, 'R'], [129, 'R'], [131, 'R'], [133, 'R'], [134, 'R'], [135, 'R'], [137, 'R'], [142, 'R'], [145, 'R'], [147, 'R'], [148, 'R'], [151, 'R'], [154, 'R'], [156, 'R'], [160, 'R'], [164, 'R'], [165, 'R'], [166, 'R'], [169, 'R'], [172, 'R'], [173, 'R'], [174, 'R'], [175, 'R'], [176, 'R'], [177, 'R'], [179, 'R'], [183, 'R'], [184, 'R'], [185, 'R'], [187, 'R'], [188, 'R'], [190, 'R'], [191, 'R'], [192, 'R'], [194, 'R'], [196, 'R'], [198, 'R'], [0, 'S'], [7, 'S'], [11, 'S'], [13, 'S'], [15, 'S'], [18, 'S'], [19, 'S'], [21, 'S'], [23, 'S'], [24, 'S'], [28, 'S'], [31, 'S'], [32, 'S'], [33, 'S'], [34, 'S'], [35, 'S'], [36, 'S'], [42, 'S'], [43, 'S'], [44, 'S'], [47, 'S'], [49, 'S'], [50, 'S'], [51, 'S'], [52, 'S'], [53, 'S'], [54, 'S'], [60, 'S'], [62, 'S'], [63, 'S'], [64, 'S'], [67, 'S'], [69, 'S'], [70, 'S'], [71, 'S'], [72, 'S'], [74, 'S'], [75, 'S'], [77, 'S'], [78, 'S'], [80, 'S'], [81, 'S'], [82, 'S'], [85, 'S'], [86, 'S'], [88, 'S'], [95, 'S'], [96, 'S'], [101, 'S'], [102, 'S'], [104, 'S'], [105, 'S'], [107, 'S'], [108, 'S'], [110, 'S'], [111, 'S'], [112, 'S'], [113, 'S'], [115, 'S'], [117, 'S'], [118, 'S'], [119, 'S'], [120, 'S'], [121, 'S'], [123, 'S'], [128, 'S'], [129, 'S'], [136, 'S'], [137, 'S'], [138, 'S'], [139, 'S'], [140, 'S'], [146, 'S'], [148, 'S'], [152, 'S'], [162, 'S'], [164, 'S'], [166, 'S'], [167, 'S'], [168, 'S'], [169, 'S'], [171, 'S'], [172, 'S'], [173, 'S'], [174, 'S'], [176, 'S'], [180, 'S'], [184, 'S'], [185, 'S'], [186, 'S'], [188, 'S'], [189, 'S'], [190, 'S'], [192, 'S'], [193, 'S'], [194, 'S'], [195, 'S'], [196, 'S'], [198, 'S'], [199, 'S']]
# ---Barrier Process S-----
#  ---> Process T resumes
# T sent 0 to R
# T sent 7 to R
# T sent 13 to R
# T sent 15 to R
# T sent 18 to R
# T sent 19 to R
# T sent 21 to R
# T sent 31 to R
# T sent 35 to R
# T sent 36 to R
# T sent 44 to R
# T sent 47 to R
# T sent 49 to R
# T sent 62 to R
# T sent 64 to R
# T sent 67 to R
# T sent 69 to R
# T sent 70 to R
# T sent 74 to R
# T sent 77 to R
# T sent 78 to R
# T sent 95 to R
# T sent 96 to R
# T sent 110 to R
# T sent 113 to R
# T sent 120 to R
# T sent 128 to R
# T sent 129 to R
# T sent 137 to R
# T sent 148 to R
# T sent 164 to R
# T sent 166 to R
# T sent 169 to R
# T sent 172 to R
# T sent 173 to R
# T sent 174 to R
# T sent 176 to R
# T sent 184 to R
# T sent 185 to R
# T sent 188 to R
# T sent 190 to R
# T sent 192 to R
# T sent 194 to R
# T sent 196 to R
# T sent 198 to R
# [[0, 'T'], [7, 'T'], [13, 'T'], [15, 'T'], [18, 'T'], [19, 'T'], [21, 'T'], [31, 'T'], [35, 'T'], [36, 'T'], [44, 'T'], [47, 'T'], [49, 'T'], [62, 'T'], [64, 'T'], [67, 'T'], [69, 'T'], [70, 'T'], [74, 'T'], [77, 'T'], [78, 'T'], [95, 'T'], [96, 'T'], [110, 'T'], [113, 'T'], [120, 'T'], [128, 'T'], [129, 'T'], [137, 'T'], [148, 'T'], [164, 'T'], [166, 'T'], [169, 'T'], [172, 'T'], [173, 'T'], [174, 'T'], [176, 'T'], [184, 'T'], [185, 'T'], [188, 'T'], [190, 'T'], [192, 'T'], [194, 'T'], [196, 'T'], [198, 'T']]
# ---Ended Process T-----
#  ---> Process R resumes
# [0, 'Stephanie'] sent 0 to S
# [7, 'Shannon'] sent 7 to S
# [13, 'Julian'] sent 13 to S
# [15, 'Veronica'] sent 15 to S
# [18, 'Thomas'] sent 18 to S
# [19, 'Willard'] sent 19 to S
# [21, 'Kimberly'] sent 21 to S
# [31, 'Michelle'] sent 31 to S
# [35, 'Jennifer'] sent 35 to S
# [36, 'Kourtney'] sent 36 to S
# [44, 'Cindy'] sent 44 to S
# [47, 'Andrew'] sent 47 to S
# [49, 'Mike'] sent 49 to S
# [62, 'Trudy'] sent 62 to S
# [64, 'Lecia'] sent 64 to S
# [67, 'Terry'] sent 67 to S
# [69, 'Frances'] sent 69 to S
# [70, 'Amelia'] sent 70 to S
# [74, 'Jerry'] sent 74 to S
# [77, 'Kimberly'] sent 77 to S
# [78, 'Helen'] sent 78 to S
# [95, 'Annette'] sent 95 to S
# [96, 'Darlene'] sent 96 to S
# [110, 'Linda'] sent 110 to S
# [113, 'Mary'] sent 113 to S
# [120, 'Denise'] sent 120 to S
# [128, 'Eddie'] sent 128 to S
# [129, 'Anita'] sent 129 to S
# [137, 'Karen'] sent 137 to S
# [148, 'Nicholas'] sent 148 to S
# [164, 'Mary'] sent 164 to S
# [166, 'Jacqueline'] sent 166 to S
# [169, 'Carmen'] sent 169 to S
# [172, 'Vivian'] sent 172 to S
# [173, 'Exie'] sent 173 to S
# [174, 'John'] sent 174 to S
# [176, 'Gilbert'] sent 176 to S
# [184, 'William'] sent 184 to S
# [185, 'Rafael'] sent 185 to S
# [188, 'Mitchell'] sent 188 to S
# [190, 'Marion'] sent 190 to S
# [192, 'Mary'] sent 192 to S
# [194, 'Tamara'] sent 194 to S
# [196, 'Debra'] sent 196 to S
# [198, 'Jeffrey'] sent 198 to S
# ---Ended Process R-----
#  ---> Process S resumes
# [0, 'Huffman'][0, 'Stephanie']
# [7, 'Tilley'][7, 'Shannon']
# [13, 'Ramirez'][13, 'Julian']
# [15, 'Gregg'][15, 'Veronica']
# [18, 'Stull'][18, 'Thomas']
# [19, 'Fontenot'][19, 'Willard']
# [21, 'Moran'][21, 'Kimberly']
# [31, 'Shiro'][31, 'Michelle']
# [35, 'Hambrick'][35, 'Jennifer']
# [36, 'Outen'][36, 'Kourtney']
# [44, 'Campos'][44, 'Cindy']
# [47, 'Tucker'][47, 'Andrew']
# [49, 'Barfield'][49, 'Mike']
# [62, 'Jones'][62, 'Trudy']
# [64, 'Brown'][64, 'Lecia']
# [67, 'Daley'][67, 'Terry']
# [69, 'Hittle'][69, 'Frances']
# [70, 'Lajoie'][70, 'Amelia']
# [74, 'Downey'][74, 'Jerry']
# [77, 'Copeland'][77, 'Kimberly']
# [78, 'Harrington'][78, 'Helen']
# [95, 'Brown'][95, 'Annette']
# [96, 'Conn'][96, 'Darlene']
# [110, 'Kendall'][110, 'Linda']
# [113, 'Walls'][113, 'Mary']
# [120, 'Richmond'][120, 'Denise']
# [128, 'Scholl'][128, 'Eddie']
# [129, 'Rouse'][129, 'Anita']
# [137, 'Tyler'][137, 'Karen']
# [148, 'Wood'][148, 'Nicholas']
# [164, 'Gillard'][164, 'Mary']
# [166, 'Cottrill'][166, 'Jacqueline']
# [169, 'Alexander'][169, 'Carmen']
# [172, 'Mccabe'][172, 'Vivian']
# [173, 'Aldrich'][173, 'Exie']
# [174, 'Moore'][174, 'John']
# [176, 'Estes'][176, 'Gilbert']
# [184, 'Hamlett'][184, 'William']
# [185, 'Adkins'][185, 'Rafael']
# [188, 'Delgado'][188, 'Mitchell']
# [190, 'Hayes'][190, 'Marion']
# [192, 'Wasmund'][192, 'Mary']
# [194, 'Toppa'][194, 'Tamara']
# [196, 'Jones'][196, 'Debra']
# [198, 'Davis'][198, 'Jeffrey']
# ---Ended Process S-----
